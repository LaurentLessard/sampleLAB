# %%
using MATLAB
using PyPlot

# %%
delta = 25 #linspace(10,40,10);
n = zeros(length(delta),1);

# %%
for d = 1:length(delta)
    figure()
    coord = mxcall(:sampleLAB,1,delta[d])
    n[d] = length(coord[:,1]);
end
# Out:
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)

# %%
plot(delta,n)
title("Tradeoff between number of colors obtained vs delta")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000043A7630>)
# PyObject <matplotlib.text.Text object at 0x0000000004418630>
