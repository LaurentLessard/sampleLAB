# %%
using MATLAB
using PyPlot

# %%
delta = 10:30 #linspace(10,40,10);
n = zeros(length(delta),1);

# %%
for d = 1:length(delta)
   coord = mxcall(:sampleLAB,1,delta[d])
   n[d] = length(coord[:,1]);
end
# Out:
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)
# Warning: Ignoring extra legend entries.
# > In legend>set_children_and_strings (line 674)
#   In legend>make_legend (line 346)
#   In legend (line 294)
#   In sampleLAB (line 26)

# %%
plot(delta,n)
title("Tradeoff between number of colors obtained vs delta")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000001F5A6A0>)
# PyObject <matplotlib.text.Text object at 0x0000000000EC6B00>
